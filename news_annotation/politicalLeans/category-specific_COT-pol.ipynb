# %% [markdown]
# ## Generate cretria for each sentement and examples

# %%
# Ensure your OpenAI API key is set
import pandas as pd
import json
import os

from langchain import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI


os.environ["OPENAI_API_KEY"] = "your_api_key"
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
model_name="gpt-4o"
#gpt-3.5-turbo

temperature=0.7
max_tokens=500

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("ctg_1example_pol.csv")
df
# Out:
#                 Category                                               Left  \
# 0                  music  Barbra Streisand shares cartoon of Pelosi kill...
# 1             basketball  Baltimore Hits 300 Homicides For 5th Consecuti...
# 2                 movies  'My 82-year-old bones hurt': Jane Fonda spent ...
# 3               baseball  Can James Wiseman and Memphis topple the NCAA ...
# 4              lifestyle  1619 Project reporter details series about 400...
# 5                weather  Marginalized communities often bear the brunt ...
# 6                 travel  Mayor de Blasio introduces Outreach NYC. The d...
# 7                  autos  D.C. empowers bike lane enforcement officers t...
# 8   scienceandtechnology  Mediterranean basin badly hit by climate chang...
# 9               morenews  Universal healthcare is essential for a just s...
# 10              politics  Billboard warns 'Moscow Mitch' McConnell: Impe...
# 11              football  'Rooting for the Gophers': Klobuchar sides wit...
# 12                 video  See Biden's lighthearted 'coming out' moment. ...
# 13                    tv  Television networks are making strides in dive...
# 14                    us  Report: Yale student fighting mother's detenti...
# 15               finance  Warren unveils a $1 trillion environmental jus...
# 16                 crime  Progressive activists call for comprehensive c...
# 17                 world  Catalan President Makes Secession Pledge in Ch...
# 18            moresports  Megan Rapinoe calls fines for racist abuse 'an...
# 19                health  Mom-of-4 with Incurable Cancer, 45, Plans Her ...
# 20         entertainment  Call of Duty: Modern Warfare is getting review...
# 21          foodanddrink  Restaurant Owners Should Embrace and Pay Above...
#
#                                                Center  \
# 0   Drake Has Something to Say to the ''Kids'' Who...
# 1   Basketball programs in schools play a crucial ...
# 2   Billie Lourd reflects on mom Carrie Fisher and...
# 3   The College Hoops Contender Series: Who are th...
# 4   Thousands of animals around the world are at r...
# 5   California governor "owns" blackouts, takes po...
# 6   Kroger shooting witness' car impounded as evid...
# 7   One of the Most Controversial F1 Crashes Ever ...
# 8   A Google Fitbit means new possibilities and qu...
# 9   Pete Buttigieg clarifies views on the Obama ad...
# 10  GOP lawmakers fear Trump becoming too consumed...
# 11  SHOCKING UPSET: Falcons beat Saints 26-9. In o...
# 12  Taylor's opening statement was 40 mins. Hear t...
# 13  Pregnant Jenna Dewan Says Daughter Everly, 6, ...
# 14  Search For Carjacker Who Stole Van Carrying Do...
# 15  Here Are The 500 Best STEM High Schools In Ame...
# 16  No injuries reported in Kalamazoo house fire. ...
# 17  Inside Mike Pence's 9 hours in Turkey. When Vi...
# 18  Tennessee officer struck while investigating a...
# 19  Dementia diagnoses may be late in women becaus...
# 20  Will Smith gets friendly with fans, plus more ...
# 21  I Only Want To Wear These Heated Dumpling Slip...
#
#                                                 Right
# 0   Music education is crucial for fostering creat...
# 1   Trump welcomes Washington Nationals to White H...
# 2   Family films promoting traditional values are ...
# 3   Baseball’s success highlights the benefits of ...
# 4   Self-reliance in personal finance is key to a ...
# 5   Local communities must take initiative in weat...
# 6   Traveling within the country boosts local econ...
# 7   Buying American-made vehicles supports domesti...
# 8   Tim Cook to host Donald Trump at Texas Apple f...
# 9   Strong national security policies are essentia...
# 10  Protecting constitutional rights is essential ...
# 11  Arizona Cardinals fans threaten to stop follow...
# 12  Major video platforms are increasingly accused...
# 13  'The View': Joy Behar lists president's scanda...
# 14  Federal judge overturns ObamaCare transgender ...
# 15  Recent tax cuts are driving economic growth, w...
# 16  He was one of the first prisoners released und...
# 17  With increasing global threats, a strong natio...
# 18  As society evolves, conservatives stress the i...
# 19  Conservative leaders advocate for individual r...
# 20  Conservative groups are advocating for more fa...
# 21  Conservatives emphasize the importance of supp...

# %%
# Function to generate criteria string for a given category
def generate_criteria(category):
    
    prompt_template = """
   Generate detailed criteria for determining the political lean (left, center, or right) of {category} news articles. 
   Provide comprehensive and specific criteria for identifying left, center, 
   or right political lean within the context of {category} news category. 
   Include content types that typically correspond to each sentiment classification.
   
   Your response only has the description of each political lean.
   Please provide the response without using any formatting symbols like asterisks or hashtags.    

   
    
    Left:
    

    Center:
    

    Right:
    
    """

        # Create the prompt template
    prompt = PromptTemplate(input_variables=["category"], template=prompt_template)

    # Initialize the ChatOpenAI model
    llm = ChatOpenAI(model_name=model_name, openai_api_key=openai_api_key, temperature=temperature, max_tokens=max_tokens)
    # Create the LLMChain with the prompt and the LLM
    chain = LLMChain(prompt=prompt, llm=llm)
    result = chain.run(category=category)
    return result.strip()

# %%
def generate_CoTExamples(category, criteria_string, left, center, right):
    
    prompt_template ="""
    You will be provided with three news articles about {category}. 
    Your role is to determine the political lean of the articles. 
    Use the following this step-by-step approach:
    
    1. Identify key points in the article.
    2. Determine political lean indicators in the article based on the criteria: {criteria_string}
    3. Conclude the overall political lean.
    
    Your response should have the following structure. 
    Please provide the response without using any formatting symbols like asterisks or hashtags.    
    
    Article 1: {left}
    1. Key points: 
    2. Political lean indicators:
    3. Political lean:

    Article 2: {center}
    1. Key points: 
    2. Political lean indicators:
    3. Political lean:
    
    
    Article 3: {right}
    1. Key points: 
    2. Political lean indicators:
    3. Political lean:
    
    
    """
    # Create the prompt template
    prompt = PromptTemplate(input_variables=["category", "criteria_string", "left", "center", "right"], template=prompt_template)
    # Initialize the ChatOpenAI model
    llm = ChatOpenAI(model_name=model_name, openai_api_key=openai_api_key, temperature=0.2, max_tokens=max_tokens)
    # Create the LLMChain with the prompt and the LLM
    chain = LLMChain(prompt=prompt, llm=llm)
    result = chain.run(category=category, criteria_string=criteria_string, left=left, center=center, right=right)
    return result.strip()

# %%
def parse_criteria(combined_string):
    criteria = {"left": [], "center": [], "right": []}
    examples = []
    current_section = None

    for line in combined_string.split('\n'):
        line = line.strip()
        if line.startswith("Left:"):
            current_section = "left"
        elif line.startswith("Center:"):
            current_section = "center"
        elif line.startswith("Right:"):
            current_section = "right"
        elif line.startswith("Article"):
            current_section = "articles"
            examples.append(line)  # Start a new article
        elif current_section and line:
            if current_section == "articles":
                examples.append(line)
            else:
                criteria[current_section].append(line)

    return criteria, "\n".join(examples)




# Generate criteria for each category and format them into a configuration


categories = df['Category'].tolist()
left = df['Left'].tolist()
center = df['Center'].tolist()
right = df['Right'].tolist()

for i in range(len(categories)):
    config = {}
    criteria_string = generate_criteria(categories[i])
    examples_string= generate_CoTExamples(categories[i], criteria_string, left[i], center[i], right[i])
    combined_string = criteria_string + "\n" + examples_string

    criteria, examples = parse_criteria(combined_string)
    config = {
        categories[i]: {
            "left": " ".join(criteria["left"]),
            "center": " ".join(criteria["center"]),
            "right": " ".join(criteria["right"]),
            "chain_of_thought_examples": examples.strip()
        }
    }

    # Save the configuration to a JSON file
    path= "pol_criteria_examples/"
    with open(path+categories[i]+'.json', 'w') as file:
        json.dump(config, file, indent=4)

    print("Configuration file created with generated criteria and chain of thought examples.")
# Out:
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.

# %% [markdown]
# ## Convert JSON file to txt

# %%
import json
import os
import glob

def convert_json_to_text(json_data):
    output = []

    for category, sentiments in json_data.items():
        output.append(f"{category.capitalize()}:\n")
        for sentiment, text in sentiments.items():
            text = text.replace('\\u2019', "'")
            output.append(f"{sentiment.capitalize()}:\n{text}\n")

    return "\n".join(output)



txt_path="pol_criteria_examples/txtFiles/"
json_path= "pol_criteria_examples/"


# Use glob to get all the JSON files in the directory
json_files = glob.glob(os.path.join(json_path, '*.json'))

# Loop through the JSON files
for json_file in json_files:
    with open(json_file, 'r') as file1:
        json_data = json.load(file1)

    text_output = convert_json_to_text(json_data)
    
    # Correctly form the file name by joining the directory and the file name
    file_name = os.path.join(txt_path, list(json_data.keys())[0] + ".txt")
    with open(file_name, 'w') as file2:
        file2.write(text_output)

    print(f"Conversion complete! Check the '{file_name}' file.")
# Out:
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/video.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/entertainment.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/travel.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/finance.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/politics.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/health.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/baseball.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/moresports.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/movies.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/us.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/autos.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/basketball.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/morenews.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/crime.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/football.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/foodanddrink.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/music.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/lifestyle.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/weather.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/tv.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/world.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/pol_criteria_examples/txtFiles/scienceandtechnology.txt' file.
