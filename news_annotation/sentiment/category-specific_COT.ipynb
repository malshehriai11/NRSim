# %% [markdown]
# ## Generate cretria for each sentement and COT examples

# %%
# Ensure your OpenAI API key is set
import pandas as pd
import json
import os

from langchain import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI


os.environ["OPENAI_API_KEY"] = "your_key_here"
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
model_name="gpt-4o"
#gpt-3.5-turbo

temperature=0.7
max_tokens=500

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("ctg_1example_pol.csv")
df
# Out:
#                 Category                                           Negative  \
# 0               morenews  Adopt a Pet: Marcelo from Houndhaven. Linda Co...
# 1   scienceandtechnology  Sea level will rise for centuries. We can cont...
# 2           foodanddrink  Dairy farmers are in crisis and it could chang...
# 3                  autos  U-Haul truck, truck carrying oversize load cra...
# 4                     us  Chicago Teachers Union To March Through City T...
# 5                  music  Former KNCI DJ Dan Cheatham Found Dead In His ...
# 6               politics  Robert Blair: Who is the White House aide refu...
# 7                     tv  'RHOC' Star Meghan Edmonds' Ex-Nanny Making Mo...
# 8                finance  Amazon's new weapon to crush competition: $1 i...
# 9                  video  Coalition of conservative groups files ethics ...
# 10               weather  Climate havoc wipes out coastal kelp as SF Bay...
# 11                 crime  Suspect arrested in disappearance of college s...
# 12            moresports  Blue Jackets coach John Tortorella has skin ca...
# 13                 world  Brazil police arrest man said to be one of wor...
# 14              baseball  Cassius Winston posts double-double a day afte...
# 15                health  Suicide deaths increasing among Ohioans, accor...
# 16              football  \"She lived every day as if it were her last,\...
# 17                travel  Virginia Beach Human Rights commissioner who s...
# 18                movies  Priscilla and Lisa Marie Presley are Not on th...
# 19         entertainment  WWE 2K20 Is Broken In Every Possible Way. Befo...
# 20             lifestyle  Meghan Markle is being criticized for doing th...
# 21            basketball  Suzyn Waldman hasn't watched the World Series ...
#
#                                               Neutral  \
# 0   Advocacy groups push Senate to include electio...
# 1   Scientists Have Calculated a New Estimate for ...
# 2   How To Open a Can Without a Can Opener. All it...
# 3   X019 won't have any Xbox Project Scarlett news...
# 4   The cheapest apartments for rent in Alhambra, ...
# 5   The 25 best soundtracks of the '90s. It was th...
# 6   Deval Patrick in race to make Democrat debate ...
# 7   Stars who've been on one show for a long time....
# 8   Historic Plant City Coronet Bungalow Up For Sa...
# 9   The celestial spectacle humans will never see....
# 10  MoDOT says the main concern for drivers Tuesda...
# 11  Carolina woman celebrates her 110th birthday. ...
# 12  NASCAR starting lineup at Phoenix: Top 10 load...
# 13  Putin: Trump Visit to Moscow for Military Para...
# 14  College Basketball Cheerleaders. College Baske...
# 15  Exactly What Happens to Your Body When You Gai...
# 16  Panthers Tracks: Kyle Allen or Teddy Bridgewat...
# 17  Starting next month, new regulations for inter...
# 18  Favorite Halloween movies ranked. We're counti...
# 19  100 books to read in a lifetime according to A...
# 20  Science says people decide these 12 things wit...
# 21  'Astrodamus' predicts Astros will win the Worl...
#
#                                              Positive
# 0   Separated pit bulls 'hit doggie lottery' as Ma...
# 1   8BitDo turns the NES gamepad into a mouse. Man...
# 2   Annual pancake breakfast, parade honor those w...
# 3   2020 Audi R8 Performance Review: What Makes Th...
# 4   Middletown's irrepressible cool: On what accou...
# 5   Women rule the night at the CMA Awards. Women ...
# 6   Three women nominated to fill vacant Democrati...
# 7   Ohio's pink tax repeal signed into law. Ohio's...
# 8   Stocks close higher after Fed signals pause on...
# 9   World Series champion Nationals parade through...
# 10  How Hamilton's 'urban forest' is blossoming wi...
# 11  US Marshals find 3 missing children from Misso...
# 12  Veterans, first responders, surfers paddle fro...
# 13  Bolivians jam streets to celebrate president's...
# 14  Big D: Dallas renames street Nowitzki Way to h...
# 15  This Bride Got a Wedding Redo After Losing 100...
# 16  Charlotte 49ers roll past Middle Tennessee for...
# 17  Hotel on Versailles grounds: Le Grand Contrôle...
# 18  Watch 'Say Anything' with John Cusack this wee...
# 19  Kate Upton Shares Rare Pic of Daughter Cheerin...
# 20  South Jersey gardener uses YouTube to share he...
# 21  Mets have a stud in Pete Alonso, but will they...

# %%
# Function to generate criteria string for a given category
def generate_criteria(category):
    
    prompt_template = """
   Generate detailed criteria for determining the sentiment of {category} news articles. 
   Provide comprehensive and specific criteria for identifying positive, negative, and neutral sentiments within the context of {category} news category. 
   Include content types that typically correspond to each sentiment classification.
   
   Your response only has the description of each sentiment.
   Please provide the response without using any formatting symbols like asterisks or hashtags.    

   
    
    Positive:
    

    Negative:
    

    Neutral:
    
    """

        # Create the prompt template
    prompt = PromptTemplate(input_variables=["category"], template=prompt_template)

    # Initialize the ChatOpenAI model
    llm = ChatOpenAI(model_name=model_name, openai_api_key=openai_api_key, temperature=temperature, max_tokens=max_tokens)
    # Create the LLMChain with the prompt and the LLM
    chain = LLMChain(prompt=prompt, llm=llm)
    result = chain.run(category=category)
    return result.strip()

# %%
def generate_CoTExamples(category, criteria_string, negative, neutral, positive):
    
    prompt_template ="""
    You will be provided with three news articles about {category}. 
    Your role is to determine the sentiment of the articles. 
    Use the following this step-by-step approach:
    
    1. Identify key points in the article.
    2. Determine sentiment indicators in the article based on the criteria: {criteria_string}
    3. Conclude the overall sentiment.
    
    Your response should have the following structure. 
    Please provide the response without using any formatting symbols like asterisks or hashtags.    
    
    Article 1: {negative}
    1. Key points: 
    2. Sentiment indicators:
    3. Sentiment:

    Article 2: {neutral}
    1. Key points: 
    2. Sentiment indicators:
    3. Sentiment:
    
    
    Article 3: {positive}
    1. Key points: 
    2. Sentiment indicators:
    3. Sentiment:
    
    
    """
    # Create the prompt template
    prompt = PromptTemplate(input_variables=["category", "criteria_string", "negative", "neutral", "positive"], template=prompt_template)
    # Initialize the ChatOpenAI model
    llm = ChatOpenAI(model_name=model_name, openai_api_key=openai_api_key, temperature=0.2, max_tokens=max_tokens)
    # Create the LLMChain with the prompt and the LLM
    chain = LLMChain(prompt=prompt, llm=llm)
    result = chain.run(category=category, criteria_string=criteria_string, negative=negative, neutral=neutral, positive=positive)
    return result.strip()

# %%
def parse_criteria(combined_string):
    criteria = {"positive": [], "negative": [], "neutral": []}
    examples = []
    current_section = None

    for line in combined_string.split('\n'):
        line = line.strip()
        if line.startswith("Positive:"):
            current_section = "positive"
        elif line.startswith("Negative:"):
            current_section = "negative"
        elif line.startswith("Neutral:"):
            current_section = "neutral"
        elif line.startswith("Article"):
            current_section = "articles"
            examples.append(line)  # Start a new article
        elif current_section and line:
            if current_section == "articles":
                examples.append(line)
            else:
                criteria[current_section].append(line)

    return criteria, "\n".join(examples)




# Generate criteria for each category and format them into a configuration


categories = df['Category'].tolist()
negative = df['Negative'].tolist()
neutral = df['Neutral'].tolist()
positive = df['Positive'].tolist()

for i in range(len(categories)):
    config = {}
    criteria_string = generate_criteria(categories[i])
    examples_string= generate_CoTExamples(categories[i], criteria_string, negative[i], neutral[i], positive[i])
    combined_string = criteria_string + "\n" + examples_string

    criteria, examples = parse_criteria(combined_string)
    config = {
        categories[i]: {
            "positive": " ".join(criteria["positive"]),
            "negative": " ".join(criteria["negative"]),
            "neutral": " ".join(criteria["neutral"]),
            "chain_of_thought_examples": examples.strip()
        }
    }

    # Save the configuration to a JSON file
    path= "snt_criteria_examples/"
    with open(path+categories[i]+'.json', 'w') as file:
        json.dump(config, file, indent=4)

    print("Configuration file created with generated criteria and chain of thought examples.")
# Out:
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.
# Configuration file created with generated criteria and chain of thought examples.

# %% [markdown]
# ## Convert JSON file to txt

# %%
import json
import os
import glob

def convert_json_to_text(json_data):
    output = []

    for category, sentiments in json_data.items():
        output.append(f"{category.capitalize()}:\n")
        for sentiment, text in sentiments.items():
            text = text.replace('\\u2019', "'")
            output.append(f"{sentiment.capitalize()}:\n{text}\n")

    return "\n".join(output)



txt_path="snt_criteria_examples/txtFiles/"
json_path= "snt_criteria_examples/"


# Use glob to get all the JSON files in the directory
json_files = glob.glob(os.path.join(json_path, '*.json'))

# Loop through the JSON files
for json_file in json_files:
    with open(json_file, 'r') as file1:
        json_data = json.load(file1)

    text_output = convert_json_to_text(json_data)
    
    # Correctly form the file name by joining the directory and the file name
    file_name = os.path.join(txt_path, list(json_data.keys())[0] + ".txt")
    with open(file_name, 'w') as file2:
        file2.write(text_output)

    print(f"Conversion complete! Check the '{file_name}' file.")
# Out:
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/video.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/entertainment.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/travel.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/finance.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/politics.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/health.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/baseball.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/moresports.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/movies.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/us.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/autos.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/basketball.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/morenews.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/crime.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/football.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/foodanddrink.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/music.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/lifestyle.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/weather.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/tv.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/world.txt' file.
# Conversion complete! Check the '/home/alshma0a/PycharmProjects/Agent4Rec_v2/my notebook/snt_criteria_examples/txtFiles/scienceandtechnology.txt' file.
